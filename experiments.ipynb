# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pickle

# %%
df=pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
## preprocess the data
## drop irrelvent features
df=df.drop(['RowNumber','CustomerId','Surname'], axis=1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0          619    France  Female  ...               1        101348.88       1
# 1          608     Spain  Female  ...               1        112542.58       0
# 2          502    France  Female  ...               0        113931.57       1
# 3          699    France  Female  ...               0         93826.63       0
# 4          850     Spain  Female  ...               1         79084.10       0
#
# [5 rows x 11 columns]

# %%
## encoding categorical variable
label_encoder_gender=LabelEncoder()
df['Gender']=label_encoder_gender.fit_transform(df['Gender'])

# %%
df
# Out:
#       CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0             619    France       0  ...               1        101348.88       1
# 1             608     Spain       0  ...               1        112542.58       0
# 2             502    France       0  ...               0        113931.57       1
# 3             699    France       0  ...               0         93826.63       0
# 4             850     Spain       0  ...               1         79084.10       0
# ...           ...       ...     ...  ...             ...              ...     ...
# 9995          771    France       1  ...               0         96270.64       0
# 9996          516    France       1  ...               1        101699.77       0
# 9997          709    France       0  ...               1         42085.58       1
# 9998          772   Germany       1  ...               0         92888.52       1
# 9999          792    France       0  ...               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
## Onehot encoding for geography column
from sklearn.preprocessing import OneHotEncoder
onehot = OneHotEncoder(sparse_output=False)  # Ensure it returns a dense array

# Fit-transform the data
encoded_values = onehot.fit_transform(df[['Geography']])

# Retrieve correct column names from OneHotEncoder
encoded_columns = onehot.get_feature_names_out(['Geography'])

# Convert the NumPy array to a DataFrame with the correct column names
encoded_df = pd.DataFrame(encoded_values, columns=encoded_columns)

# Concatenate with original DataFrame (optional)
df = pd.concat([df, encoded_df], axis=1)

# %%
df.head()
# Out:
#    CreditScore Geography  ...  Geography_Germany  Geography_Spain
# 0          619    France  ...                0.0              0.0
# 1          608     Spain  ...                0.0              1.0
# 2          502    France  ...                0.0              0.0
# 3          699    France  ...                0.0              0.0
# 4          850     Spain  ...                0.0              1.0
#
# [5 rows x 14 columns]

# %%
df=df.drop(columns=['Geography'])

# %%
df.head()
# Out:
#    CreditScore  Gender  ...  Geography_Germany  Geography_Spain
# 0          619       0  ...                0.0              0.0
# 1          608       0  ...                0.0              1.0
# 2          502       0  ...                0.0              0.0
# 3          699       0  ...                0.0              0.0
# 4          850       0  ...                0.0              1.0
#
# [5 rows x 13 columns]

# %%
## save the encoder ans scaler
with open('label_encoder_gender.pkl','wb') as file:
    pickle.dump(label_encoder_gender, file)

with open('onehot_encoder_geo.pkl','wb') as file:
    pickle.dump(onehot, file)

# %%
## divide the data set into independent an d dependent
x=df.drop('Exited', axis=1)
y=df['Exited']

x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=.2, random_state=42)

## scle these feature
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.35649971,  0.91324755, -0.6557859 , ...,  1.00150113,
#         -0.57946723, -0.57638802],
#        [-0.20389777,  0.91324755,  0.29493847, ..., -0.99850112,
#          1.72572313, -0.57638802],
#        [-0.96147213,  0.91324755, -1.41636539, ..., -0.99850112,
#         -0.57946723,  1.73494238],
#        ...,
#        [ 0.86500853, -1.09499335, -0.08535128, ...,  1.00150113,
#         -0.57946723, -0.57638802],
#        [ 0.15932282,  0.91324755,  0.3900109 , ...,  1.00150113,
#         -0.57946723, -0.57638802],
#        [ 0.47065475,  0.91324755,  1.15059039, ..., -0.99850112,
#          1.72572313, -0.57638802]])

# %%
with open('scaler.pkl','wb') as file:
    pickle.dump(scaler, file)

# %% [markdown]
# Ann Implementation

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import datetime

# %%
x_train.shape[1]
# Out:
# 12

# %%
## build Our ANN model
model=Sequential(
    [
        Dense(64, activation='relu',input_shape=(x_train.shape[1],)), # 1st hidden layer, in this we have to write inpute size
        Dense(32,activation='relu'),  # hideen layer 2
        Dense(1, activation='sigmoid') ## output layer
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_55 (Dense)            (None, 64)                832
#
#  dense_56 (Dense)            (None, 32)                2080
#
#  dense_57 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2945 (11.50 KB)
# Trainable params: 2945 (11.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
opt=tf.keras.optimizers.Adam(learning_rate=0.01)  ##  for providing own learning rate
loss=tf.keras.losses.BinaryCrossentropy()   ## for setting anyy loss

# %%
## compile the model
model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])

# %%
## set up the tensorboard
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorflow_callback=TensorBoard(log_dir=log_dir,histogram_freq=1)

# %%
## setup early stopping- it is used to moderate the loss value, if it not decreasing , then early stopping stop the procedure
early_stopping_callback=EarlyStopping(monitor='val_loss',patience=15,restore_best_weights=True)

# %%
## training the model
history=model.fit(
    x_train,y_train, validation_data=(x_test,y_test), epochs=100,
    callbacks=[tensorflow_callback,early_stopping_callback]
)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 2s 3ms/step - loss: 0.3968 - accuracy: 0.8386 - val_loss: 0.3512 - val_accuracy: 0.8635
# Epoch 2/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3553 - accuracy: 0.8550 - val_loss: 0.3555 - val_accuracy: 0.8590
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3484 - accuracy: 0.8574 - val_loss: 0.3491 - val_accuracy: 0.8580
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3439 - accuracy: 0.8606 - val_loss: 0.3582 - val_accuracy: 0.8575
# Epoch 5/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3408 - accuracy: 0.8614 - val_loss: 0.3532 - val_accuracy: 0.8510
# Epoch 6/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3400 - accuracy: 0.8611 - val_loss: 0.3425 - val_accuracy: 0.8640
# Epoch 7/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3351 - accuracy: 0.8651 - val_loss: 0.3415 - val_accuracy: 0.8625
# Epoch 8/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3320 - accuracy: 0.8646 - val_loss: 0.3432 - val_accuracy: 0.8660
# Epoch 9/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3306 - accuracy: 0.8644 - val_loss: 0.3429 - val_accuracy: 0.8550
# Epoch 10/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3288 - accuracy: 0.8652 - val_loss: 0.3485 - val_accuracy: 0.8560
# Epoch 11/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3269 - accuracy: 0.8685 - val_loss: 0.3453 - val_accuracy: 0.8610
# Epoch 12/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3243 - accuracy: 0.8669 - val_loss: 0.3555 - val_accuracy: 0.8595
# Epoch 13/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3243 - accuracy: 0.8690 - val_loss: 0.3697 - val_accuracy: 0.8545
# Epoch 14/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3214 - accuracy: 0.8687 - val_loss: 0.3404 - val_accuracy: 0.8595
# Epoch 15/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3219 - accuracy: 0.8695 - val_loss: 0.3522 - val_accuracy: 0.8575
# Epoch 16/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3183 - accuracy: 0.8702 - val_loss: 0.3510 - val_accuracy: 0.8585
# Epoch 17/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3165 - accuracy: 0.8695 - val_loss: 0.3600 - val_accuracy: 0.8530
# Epoch 18/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3132 - accuracy: 0.8691 - val_loss: 0.3477 - val_accuracy: 0.8605
# Epoch 19/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3073 - accuracy: 0.8754 - val_loss: 0.3575 - val_accuracy: 0.8570
# Epoch 20/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3079 - accuracy: 0.8714 - val_loss: 0.3712 - val_accuracy: 0.8555
# Epoch 21/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3081 - accuracy: 0.8736 - val_loss: 0.3532 - val_accuracy: 0.8655
# Epoch 22/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3035 - accuracy: 0.8733 - val_loss: 0.3570 - val_accuracy: 0.8555
# Epoch 23/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3037 - accuracy: 0.8740 - val_loss: 0.3588 - val_accuracy: 0.8615
# Epoch 24/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2999 - accuracy: 0.8745 - val_loss: 0.3747 - val_accuracy: 0.8535
# Epoch 25/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3014 - accuracy: 0.8749 - val_loss: 0.3574 - val_accuracy: 0.8560
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2930 - accuracy: 0.8776 - val_loss: 0.3827 - val_accuracy: 0.8600
# Epoch 27/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2951 - accuracy: 0.8773 - val_loss: 0.4076 - val_accuracy: 0.8525
# Epoch 28/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2907 - accuracy: 0.8789 - val_loss: 0.3785 - val_accuracy: 0.8560
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2886 - accuracy: 0.8774 - val_loss: 0.4100 - val_accuracy: 0.8460

# %%
model.save('model_new.h5')
# Out:
# c:\Users\ashis\Desktop\python\deep learning\venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
## load tensorboard extension
# %reload_ext tensorboard

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 3108), started 7:25:34 ago. (Use '!kill 3108' to kill it.)
#       <iframe id="tensorboard-frame-728a7b464d423e3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-728a7b464d423e3");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 3108
# Out:
# 'kill' is not recognized as an internal or external command,
# operable program or batch file.

# %%
## load the pickle file for prediction
